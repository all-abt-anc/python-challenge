# %%
# Environment Setup
# ----------------------------------------------------------------
# Dependencies
import plotly
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#sizeref = 2 * max(array of size values) / (desired maximum marker size ** 2)

# %%
city_csv_path = "raw_data/city_data.csv"
ride_csv_path = "raw_data/ride_data.csv"

# %%
city_df = pd.read_csv(city_csv_path)
ride_df = pd.read_csv(ride_csv_path)

# %%
city_df
# Out:
#                      city  driver_count      type
# 0              Kelseyland            63     Urban
# 1              Nguyenbury             8     Urban
# 2            East Douglas            12     Urban
# 3           West Dawnfurt            34     Urban
# 4          Rodriguezburgh            52     Urban
# 5       South Josephville             4     Urban
# 6        West Sydneyhaven            70     Urban
# 7             Travisville            37     Urban
# 8             Torresshire            70     Urban
# 9               Lisaville            66     Urban
# 10              Mooreview            34     Urban
# 11             Smithhaven            67     Urban
# 12            Carrollfort            55     Urban
# 13        Port Josephfurt            28     Urban
# 14       Lake Jeffreyland            15     Urban
# 15            South Louis            12     Urban
# 16             West Peter            61     Urban
# 17        Kimberlychester            13     Urban
# ...

# %%
ride_df
# Out:
#                       city                 date   fare        ride_id
# 0                 Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1                South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2              Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3              Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4               Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673
# 5              New Jeffrey  2016-02-22 18:36:25  36.01  9757888452346
# 6            Port Johnstad  2016-06-07 02:39:58  17.15  4352278259335
# 7                Jacobfort  2016-09-20 20:58:37  22.98  1500221409082
# 8              Travisville  2016-01-15 17:32:02  27.39   850152768361
# 9               Sandymouth  2016-11-16 07:27:00  21.61  2389035050524
# 10         New Andreamouth  2016-04-11 07:20:48   7.72  9992929847990
# 11           New Christine  2016-09-13 15:06:42  24.89  7918411468537
# ...

# %%
grouped_ride_df = pd.DataFrame(ride_df.groupby("city")["fare"].sum())
grouped_ride_df
# Out:
#                         fare
# city
# Alvarezhaven          741.79
# Alyssaberg            535.85
# Anitamouth            335.84
# Antoniomouth          519.75
# Aprilchester          417.65
# Arnoldview            778.30
# Campbellport          505.67
# Carrollbury           366.06
# Carrollfort           736.47
# Clarkstad             372.62
# Conwaymouth           380.51
# Davidtown             482.54
# Davistown             537.43
# East Cherylfurt       408.41
# East Douglas          575.72
# East Erin             685.39
# East Jenniferchester  619.39
# East Leslie           370.27
# East Stephen          390.53
# East Troybury         232.71
# Edwardsbury           725.67
# Erikport              240.35
# Eriktown              484.10
# Floresberg            323.10
# Fosterside            552.83
# Hernandezshire        288.02
# Horneland              85.93
# Jacksonfort           192.04
# Jacobfort             768.16
# Jasonfort             333.98
# ...                      ...
# ...

# %%
final_merged_table = pd.merge(city_df, grouped_ride_df, on="city", how="ou")
# Out:
#                         fare
# city
# Alvarezhaven          741.79
# Alyssaberg            535.85
# Anitamouth            335.84
# Antoniomouth          519.75
# Aprilchester          417.65
# Arnoldview            778.30
# Campbellport          505.67
# Carrollbury           366.06
# Carrollfort           736.47
# Clarkstad             372.62
# Conwaymouth           380.51
# Davidtown             482.54
# Davistown             537.43
# East Cherylfurt       408.41
# East Douglas          575.72
# East Erin             685.39
# East Jenniferchester  619.39
# East Leslie           370.27
# East Stephen          390.53
# East Troybury         232.71
# Edwardsbury           725.67
# Erikport              240.35
# Eriktown              484.10
# Floresberg            323.10
# Fosterside            552.83
# Hernandezshire        288.02
# Horneland              85.93
# Jacksonfort           192.04
# Jacobfort             768.16
# Jasonfort             333.98
# ...                      ...
# ...

# %%
city_df_indexed_type_only = pd.DataFrame(city_df_indexed["type"].value_counts())
city_df_indexed_type_only.reset_index(inplace=True)
city_df_indexed_type_only.columns = ["city type", "number of cities"]
city_df_indexed_type_only = city_df_indexed_type_only.reset_index()
city_df_indexed_type_only
# Out:
#    index city type  number of cities
# 0      0     Urban                66
# 1      1  Suburban                42
# 2      2     Rural                18

# %%
grouped_merge_for_pie = pd.DataFrame(merge_for_pie.groupby("type")["fare","number of Rides","driver_count", "average fare"].sum())
#grouped_merge_for_pie

# %%
grouped_merge_for_pie.reset_index(inplace=True)
grouped_merge_for_pie
# Out:
#        type      fare  number of Rides  driver_count  average fare
# 0     Rural   4255.09              125           104    615.728572
# 1  Suburban  22371.31              721           638   1300.433953
# 2     Urban  40078.34             1625          2607   1623.863390

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 10.0

# %%
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0, 0, 0.08)
labels = grouped_merge_for_pie["type"]
fig = plt.figure(figsize=[5,5])
ax = fig.add_subplot(111)
ax.pie(grouped_merge_for_pie["fare"], labels=labels, explode=explode, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140, labeldistance=1.05)
ax.set_title("% of Total Fares by City Type")

# %%
plt.axis("equal")
# Out:
# (-1.118541195314132,
#  1.1822690974338024,
#  -1.1165918628445104,
#  1.154132004137052)

# %%
plt.show()

# %%
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0, 0, 0.08)
labels = grouped_merge_for_pie["type"]
fig = plt.figure(figsize=[5,5])
ax = fig.add_subplot(111)
ax.pie(grouped_merge_for_pie["number of Rides"], labels=labels, explode=explode, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140, labeldistance=1.05)
ax.set_title("% of Total Rides by City Type")

# %%
plt.axis("equal")
# Out:
# (-1.1138011960193812,
#  1.1935921410548413,
#  -1.0949447820787257,
#  1.146165428619917)

# %%
plt.show()

# %%
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0, 0, 0.08)
labels = grouped_merge_for_pie["type"]
fig = plt.figure(figsize=[5,5])
ax = fig.add_subplot(111)
ax.pie(grouped_merge_for_pie["driver_count"], labels=labels, explode=explode, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140, labeldistance=1.05)
ax.set_title("% of Total Drivers by City Type")

# %%
plt.axis("equal")
# Out:
# (-1.1193451288312446,
#  1.1849512320808815,
#  -1.1038070776183508,
#  1.103722383970873)

# %%
plt.show()
